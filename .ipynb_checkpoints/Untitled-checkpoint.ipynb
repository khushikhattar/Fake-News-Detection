# %%
# Importing Libraries
# !pip install pandas numpy seaborn scikit-learn nltk tpot
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re
import string
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB
import nltk
# Out:
# Requirement already satisfied: pandas in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (2.1.3)
# Requirement already satisfied: seaborn in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (1.5.2)
# Requirement already satisfied: nltk in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (3.9.1)
# Requirement already satisfied: tpot in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (0.12.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: click in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from nltk) (4.66.6)
# Requirement already satisfied: deap>=1.2 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from tpot) (1.4.1)
# Requirement already satisfied: update-checker>=0.16 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from tpot) (0.18.0)
# Requirement already satisfied: stopit>=1.1.1 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from tpot) (1.1.2)
# Requirement already satisfied: xgboost>=1.1.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from tpot) (2.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: colorama in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from tqdm->nltk) (0.4.6)
# Requirement already satisfied: requests>=2.3.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from update-checker>=0.16->tpot) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2024.8.30)

# %%
# Downloading stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Acer\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Importing Dataset
df_fake = pd.read_csv("Fake.csv")
df_true = pd.read_csv("True.csv")
df_fake.head()
df_true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
# Inserting a column "class" as target feature
df_fake["class"] = 0
df_true["class"] = 1
df_fake.shape, df_true.shape
# Out:
# ((23481, 5), (21417, 5))

# %%
# Merging True and Fake Dataframes
df_merge = pd.concat([df_fake, df_true], axis=0)

# %%
# Removing unnecessary columns
df = df_merge.drop(["title", "subject", "date"], axis=1)

# %%
#Random Shuffling the dataframe
df = df.sample(frac = 1)
df.head()
df.reset_index(inplace = True)
df.drop(["index"], axis = 1, inplace = True)
df.columns
df.head()
# Out:
#                                                 text  class
# 0  With the primaries getting closer and the choi...      0
# 1  Hillary Clinton will be back in the spotlight ...      0
# 2  (Reuters) - The U.S. Senate on Monday confirme...      1
# 3  HENNIKER, N.H. (Reuters) - U.S. Democratic pre...      1
# 4  ANKARA (Reuters) - The United States is still ...      1

# %%
# Creating a function to process the texts
def wordopt(text):
    text = text.lower()
    text = re.sub(r'\[.*?\]', '', text)
    text = re.sub(r"https?://\S+|www\.\S+", '', text)
    text = re.sub(r'<.*?>+', '', text)
    text = re.sub(r'[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub(r'\n', '', text)
    text = re.sub(r'\w*\d\w*', '', text)    
    return text

# %%
# Text processing
df["text"] = df["text"].apply(wordopt)

# %%
# Defining dependent and independent variables
X = df["text"]
Y = df["class"]

# %%
# Splitting Training and Testing
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=42)

# Converting Text to Vectors
vectorization = TfidfVectorizer()
Xv_train = vectorization.fit_transform(X_train)
Xv_test = vectorization.transform(X_test)

# %%
# Function to plot confusion matrix
def plot_confusion_matrix(model_name, Y_test, Y_pred):
    cm = confusion_matrix(Y_test, Y_pred)
    plt.figure(figsize=(8, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title(f'Confusion Matrix for {model_name}')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

# %%
# Function to evaluate models
def evaluate_model(model, model_name):
    model.fit(Xv_train, Y_train)
    Y_pred = model.predict(Xv_test)

    accuracy = accuracy_score(Y_test, Y_pred)
    print(f"{model_name} Accuracy: {accuracy * 100:.2f}%")
    print(classification_report(Y_test, Y_pred))
    plot_confusion_matrix(model_name, Y_test, Y_pred)
    
    return Y_pred

# %%
# Define models
models = {
    "Logistic Regression": LogisticRegression(),
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(random_state=0),
    "K-Nearest Neighbors": KNeighborsClassifier(),
    "Naive Bayes": MultinomialNB(),
}

# Store predictions for comparison
predictions = {}

# %%
# Evaluate each model
for model_name, model in models.items():
    print(f"\nEvaluating {model_name}...")
    Y_pred = evaluate_model(model, model_name)
    predictions[model_name] = Y_pred
# Out:
# Evaluating Logistic Regression...
# Logistic Regression Accuracy: 98.74%
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5901
#            1       0.98      0.99      0.99      5324
#
#     accuracy                           0.99     11225
#    macro avg       0.99      0.99      0.99     11225
# weighted avg       0.99      0.99      0.99     11225
# Evaluating Decision Tree...
# Decision Tree Accuracy: 99.60%
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5901
#            1       1.00      1.00      1.00      5324
#
#     accuracy                           1.00     11225
#    macro avg       1.00      1.00      1.00     11225
# weighted avg       1.00      1.00      1.00     11225
# Evaluating Random Forest...
# Random Forest Accuracy: 98.67%
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5901
#            1       0.99      0.99      0.99      5324
#
#     accuracy                           0.99     11225
#    macro avg       0.99      0.99      0.99     11225
# weighted avg       0.99      0.99      0.99     11225
# Evaluating K-Nearest Neighbors...
# K-Nearest Neighbors Accuracy: 68.95%
#               precision    recall  f1-score   support
#
#            0       0.63      0.98      0.77      5901
#            1       0.94      0.37      0.53      5324
#
#     accuracy                           0.69     11225
#    macro avg       0.79      0.67      0.65     11225
# weighted avg       0.78      0.69      0.66     11225
# Evaluating Naive Bayes...
# Naive Bayes Accuracy: 93.87%
#               precision    recall  f1-score   support
#
#            0       0.94      0.95      0.94      5901
#            1       0.94      0.93      0.94      5324
#
#     accuracy                           0.94     11225
#    macro avg       0.94      0.94      0.94     11225
# weighted avg       0.94      0.94      0.94     11225

# %%
# Create a summary of the results
summary = pd.DataFrame({
    'Model': [],
    'Accuracy': [],
    'Precision': [],
    'Recall': [],
    'F1-Score': []
})

for model_name, model in models.items():
    Y_pred = predictions[model_name]
    report = classification_report(Y_test, Y_pred, output_dict=True)
    
    # Creating a new DataFrame for each model's performance
    model_performance = pd.DataFrame([{
        'Model': model_name,
        'Accuracy': accuracy_score(Y_test, Y_pred) * 100,
        'Precision': report['macro avg']['precision'] * 100,
        'Recall': report['macro avg']['recall'] * 100,
        'F1-Score': report['macro avg']['f1-score'] * 100
    }])
    
    # Concatenating the new DataFrame with the summary DataFrame
    summary = pd.concat([summary, model_performance], ignore_index=True)

print("\nSummary of Model Performance:")
print(summary)
# Out:
# Summary of Model Performance:
#                  Model   Accuracy  Precision     Recall   F1-Score
# 0  Logistic Regression  98.743875  98.731344  98.751108  98.740808
# 1        Decision Tree  99.599109  99.601287  99.594833  99.598021
# 2        Random Forest  98.672606  98.672208  98.665875  98.669003
# 3  K-Nearest Neighbors  68.953229  78.638990  67.384718  64.901112
# 4          Naive Bayes  93.870824  93.872541  93.834384  93.852007

# %%
# Function to return a label
def output_label(n):
    if n == 0:
        return "Fake News"
    elif n == 1:
        return "Not A Fake News"

# Function for manual testing of individual news articles from CSV file
def manual_testing(csv_file):
    # Load the testing data from CSV file
    testing_data = pd.read_csv(csv_file)
    
    # Ensure the CSV has a column named "text"
    if "text" not in testing_data.columns:
        print("The CSV file should have a 'text' column.")
        return

    # Apply text processing
    testing_data["text"] = testing_data["text"].apply(wordopt)
    
    # Transform the text to feature vectors
    new_xv_test = vectorization.transform(testing_data["text"])
    
    # Make predictions using each model
    for model_name, model in models.items():
        predictions = model.predict(new_xv_test)
        print(f"\n{model_name} Predictions:")
        for idx, pred in enumerate(predictions):
            print(f"Article {idx+1}: {output_label(pred)}")

# Example usage for manual testing from CSV file
csv_file = "manual_testing.csv"  # Path to the CSV file
manual_testing(csv_file)
# Out:
# Logistic Regression Predictions:
# Article 1: Fake News
# Article 2: Fake News
# Article 3: Fake News
# Article 4: Fake News
# Article 5: Fake News
# Article 6: Fake News
# Article 7: Fake News
# Article 8: Fake News
# Article 9: Fake News
# Article 10: Fake News
# Article 11: Not A Fake News
# Article 12: Not A Fake News
# Article 13: Not A Fake News
# Article 14: Not A Fake News
# Article 15: Not A Fake News
# Article 16: Not A Fake News
# Article 17: Not A Fake News
# Article 18: Not A Fake News
# Article 19: Not A Fake News
# Article 20: Not A Fake News
#
# Decision Tree Predictions:
# Article 1: Fake News
# Article 2: Fake News
# Article 3: Fake News
